# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df = pd.DataFrame({'A':1,
                   'B':1,
                   'C':["Steph","Dylan","Kate","Fred","Mike"],
                   'D':[3.14,4,5,6,7]})
df
# Out:
#    A  B      C     D
# 0  1  1  Steph  3.14
# 1  1  1  Dylan  4.00
# 2  1  1   Kate  5.00
# 3  1  1   Fred  6.00
# 4  1  1   Mike  7.00

# %%
df.dtypes
# Out:
# A      int64
# B      int64
# C     object
# D    float64
# dtype: object

# %%
df.iloc[0:2,0:3]
# Out:
#    A  B      C
# 0  1  1  Steph
# 1  1  1  Dylan

# %%
df.loc[[0,3],["A","C"]]
# Out:
#    A      C
# 0  1  Steph
# 3  1   Fred

# %%
df["A"]
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: A, dtype: int64

# %%
df["A"].shape
# Out:
# (5,)

# %%
df[["A","B"]].shape
# Out:
# (5, 2)

# %%
df[["A",'B']]
# Out:
#    A  B
# 0  1  1
# 1  1  1
# 2  1  1
# 3  1  1
# 4  1  1

# %%
my_bool = [True, False, True, False, True]
df.loc[my_bool]
# Out:
#    A  B      C     D
# 0  1  1  Steph  3.14
# 2  1  1   Kate  5.00
# 4  1  1   Mike  7.00

# %%
df_rpkms = pd.read_csv("RNA.gz", compression="gzip",skiprows=2,sep="\t")

# %%
df_rpkms #this is the amount of expression for each gene (row) and sample (column)
# Out:
#                     Name Description  GTEX-N7MS-0007-SM-2D7W1  \
# 0      ENSG00000223972.4     DDX11L1                 0.000000
# 1      ENSG00000227232.3      WASH7P                 2.917592
# 2      ENSG00000243485.1  MIR1302-11                 0.000000
# 3      ENSG00000237613.2     FAM138A                 0.000000
# 4      ENSG00000240361.1     OR4G11P                 0.000000
# ...                  ...         ...                      ...
# 52571  ENSG00000198786.2      MT-ND5               627.419189
# 52572  ENSG00000198695.2      MT-ND6               553.020569
# 52573  ENSG00000210194.1   J01415.21                 0.434417
# 52574  ENSG00000198727.2      MT-CYB              2022.417969
# 52575  ENSG00000210195.2   J01415.22                 0.000000
#
#        GTEX-N7MS-0011-R10A-SM-2HMJK  GTEX-N7MS-0011-R11A-SM-2HMJS  \
# 0                          0.000000                      0.000000
# 1                          1.958602                      5.841671
# ...

# %%
df_rpkms.median(axis = 1) #median of gene expression for each gene for all samples.
# Out:
# 0           0.000000
# 1           5.917334
# 2           0.000000
# 3           0.000000
# 4           0.000000
#             ...
# 52571    2376.176025
# 52572    2423.041016
# 52573       0.342601
# 52574    8809.516602
# 52575       0.000000
# Length: 52576, dtype: float64

# %%
roi = df_rpkms.median(axis=1) > 0 #will show all expression of genes that express more than 0
#you don't have to use an if statement because of pandas
roi
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 52571     True
# 52572     True
# 52573     True
# 52574     True
# 52575    False
# Length: 52576, dtype: bool

# %%
df_rpkms = df_rpkms.loc[roi, :]
df_rpkms
# Out:
#                     Name    Description  GTEX-N7MS-0007-SM-2D7W1  \
# 1      ENSG00000227232.3         WASH7P                 2.917592
# 6      ENSG00000238009.2   RP11-34P13.7                 0.177576
# 7      ENSG00000239945.1   RP11-34P13.8                 0.272705
# 8      ENSG00000237683.3  RP11-34P13.11                88.187675
# 9      ENSG00000239906.1  RP11-34P13.14                21.158670
# ...                  ...            ...                      ...
# 52566  ENSG00000198840.2         MT-ND3               546.563416
# 52571  ENSG00000198786.2         MT-ND5               627.419189
# 52572  ENSG00000198695.2         MT-ND6               553.020569
# 52573  ENSG00000210194.1      J01415.21                 0.434417
# 52574  ENSG00000198727.2         MT-CYB              2022.417969
#
#        GTEX-N7MS-0011-R10A-SM-2HMJK  GTEX-N7MS-0011-R11A-SM-2HMJS  \
# 1                          1.958602                      5.841671
# ...

# %%
df_metadata = pd.read_csv("GTEx.txt", sep="/t")
df_metadata
# Out:
# /Users/cmdb/miniconda3/envs/cmdb/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-17-ae3e9d6f54d7> in <module>()
# ----> 1 df_metadata = pd.read_csv("GTEx.txt", sep="/t")
#       2 df_metadata
#
# ...

# %%
df_metadata =

# %%
pca_input = df_rpkms.iloc[:,2:]
pca_input

# %%
pca_input = pca_input.T #Will transport the axis
pca_input

# %%
pca_input.mean(axis=0) #median

# %%
pca_input_standardized = StandardScaler().fit_transform #Normalize the data, will make gene expression 0

# %%
pca_input_standardized.var(axis=0)

# %%
pca=PCA(n_components = 10) #How many variables you want to study
pca_output = pca.fit_transform()#This is how you run PCA
pca_output

# %%
pca_output.shape #Size of data

# %%
#Store in a pandas data frame
pca_output_df = pd.DataFrame(data = pca_output, 
                            columns = ['PCA1','PCA2','PCA3','PCA4'.'PCA5','PCA6','PCA7','PCA8','PCA9','PCA10'])

# %%
#plot data
fig, ax = plt.subplots()
ax.scatter(x = pca_output_df['PCA1'], y=pca_output_df['PCA2'])

# %%
#How to get row names
pca_output_df['SAMPID'] = pca_input.index
pca_output_df

# %%
df_metabata #table with info on sample and type of tissue

# %%
pca_outputpd_df = pd.merge(pca_output_df,df_metadata, on='SAMPID')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-6f929570b70b> in <module>()
# ----> 1 pca_outputpd.merge(pca_output_df,df_metadata, on='SAMPID')
#
# NameError: name 'pca_outputpd' is not defined

# %%
#plot data
fig, ax = plt.subplots()
tissues = pca_output_df.grouphy("SMTS") #grouphy makes groups depending on tissue type
    ax.scatter(x=group['PC1'], y=group['PCA2'], label=name)


ax.scatter(x = pca_output_df['PCA1'], y=pca_output_df['PCA2'])

plt.legend(bbox_to_anchor = (1.7,1), loc = 'upper right', ncol=2)
